# %% [markdown]
# ## Headless scraping using Selenium
#
# This notebook does not work in the binder, needs local driver install, see below

# %% [markdown]
# #### Documentation:
# - [Requests.py](http://docs.python-requests.org)
# - [Beautifulsoup.py](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Selenium with python](https://selenium-python.readthedocs.io/)
# - [Selenium](https://www.selenium.dev/documentation/)

# %%
# Install Selenium: This needs to be executed only once!!!!!
# !pip install selenium

# Download the selenium driver for your browser and machine from
#         https://selenium-python.readthedocs.io/installation.html#drivers
# and add it to this local folder:
import os
import sys
os.path.dirname(sys.executable)
# Out:
# Collecting selenium
#   Downloading selenium-4.11.2-py3-none-any.whl (7.2 MB)
# Collecting trio~=0.17
#   Downloading trio-0.22.2-py3-none-any.whl (400 kB)
# Collecting certifi>=2021.10.8
#   Downloading certifi-2026.2.25-py3-none-any.whl (153 kB)
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Collecting urllib3[socks]<3,>=1.26
#   Downloading urllib3-2.0.7-py3-none-any.whl (124 kB)
# Requirement already satisfied: cffi>=1.14; os_name == "nt" and implementation_name != "pypy" in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.14.0)
# Collecting exceptiongroup>=1.0.0rc9; python_version < "3.11"
#   Downloading exceptiongroup-1.3.1-py3-none-any.whl (16 kB)
# Collecting outcome
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: sortedcontainers in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.1.0)
# Collecting attrs>=20.1.0
#   Downloading attrs-24.2.0-py3-none-any.whl (63 kB)
# Requirement already satisfied: idna in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.8)
# Collecting sniffio
#   Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6; extra == "socks" in c:\programdata\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.14; os_name == "nt" and implementation_name != "pypy"->trio~=0.17->selenium) (2.19)
# Collecting typing-extensions>=4.6.0; python_version < "3.13"
#   Downloading typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\programdata\anaconda3\lib\site-packages (from attrs>=20.1.0->trio~=0.17->selenium) (1.5.0)
# Collecting h11<1,>=0.9.0
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata; python_version < "3.8"->attrs>=20.1.0->trio~=0.17->selenium) (2.2.0)
# Installing collected packages: typing-extensions, exceptiongroup, attrs, outcome, sniffio, trio, certifi, h11, wsproto, trio-websocket, urllib3, selenium
#   Attempting uninstall: attrs
#     Found existing installation: attrs 19.3.0
#     Uninstalling attrs-19.3.0:
# ERROR: pytest-astropy 0.8.0 requires pytest-cov>=2.0, which is not installed.
# ERROR: pytest-astropy 0.8.0 requires pytest-filter-subpackage>=0.1, which is not installed.
# ERROR: requests 2.22.0 has requirement urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you'll have urllib3 2.0.7 which is incompatible.
# ERROR: Could not install packages due to an EnvironmentError: [WinError 5] Access is denied: 'c:\\programdata\\anaconda3\\lib\\site-packages\\attr\\converters.py'
# Consider using the `--user` option or check the permissions.
# 'C:\\ProgramData\\Anaconda3'

# %%
# Imports:
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-98f7fcaebe6c> in <module>
#       1 # Imports:
#       2 import time
# ----> 3 from selenium import webdriver
#       4 from selenium.webdriver.common.by import By
#
# ModuleNotFoundError: No module named 'selenium'

# %% [markdown]
# ## Static Price list page the old way (requests, beautifulsoup):

# %%
import requests
from bs4 import BeautifulSoup
headers = {'user-agent': 'scrapingCourseBot'}

# Pricelist first product name via beautifulsoup:
r = requests.get("https://snstatcomp.github.io/webscrapingtests/course/prices1.html", headers=headers)
soup = BeautifulSoup(r.text, 'lxml')
print(soup.select('div.name')[0].text)

# %% [markdown]
# ## Static Price list page headless via Chrome:

# %%
options = webdriver.ChromeOptions()
options.add_argument("--headless=new")
options.add_argument('user-agent=scrapingCourseBot')

browser = webdriver.Chrome(options=options)
browser.get("https://snstatcomp.github.io/webscrapingtests/course/prices1.html")

# Retrieve first item name:
elem = browser.find_element(By.CSS_SELECTOR, 'div.name')
print(elem.text)

browser.close()

# %% [markdown]
# ## Headless request to price list (Firefox):

# %%
from selenium.webdriver.firefox.options import Options
options = Options()
options.add_argument("--headless=new")
options.add_argument('user-agent=scrapingCourseBot')

browser = webdriver.Firefox(options=options)
browser.get('https://snstatcomp.github.io/webscrapingtests/course/prices1.html')

# Retrieve first item name:
elem = browser.find_element(By.CSS_SELECTOR, 'div.name')
print(elem.text)

browser.close()

# %% [markdown]
# ## Headless getting Olympic winter games (Chrome):

# %%
options = webdriver.ChromeOptions()
#options.add_argument("--headless=new")
#options.add_argument('user-agent=scrapingCourseBot')

browser = webdriver.Chrome(options=options)
browser.get('https://olympics.com/en/sports/winter-olympics')

time.sleep(5)

# Retrieve first item name:
# elements = browser.find_elements_by_css_selector('div.-sportlist h1.article--title') # this worked in Sep 2021
elements = browser.find_elements(By.CSS_SELECTOR, 'li.b2p-sports-wrapper__item') # this works in Sep 2022
for e in elements:
    print(e.text)

#browser.close()
