# %% [markdown]
# ## Exercise: Olympics

# %%
import requests
from bs4 import BeautifulSoup
import datetime as dt
import csv

# %% [markdown]
# - Retrieve a list of Olympic **summer sports** using requests.py and beautifulsoup.py and print them

# %%
www = 'https://www.olympic.org'
r = requests.get(f'{www}/sports')
soup = BeautifulSoup(r.text,'lxml')

summergames = soup.select("#summer-sports a")
for sport in summergames:
    print(sport.text.strip())
# Out:
# Archery
# Artistic Swimming
# Athletics
# Badminton
# Baseball - Softball
# Basketball
# Beach Volleyball
# Boxing
# Canoe Slalom
# Canoe Sprint
# Cycling BMX
# Cycling Mountain Bike
# Cycling Road
# Cycling Track
# Diving
# Equestrian / Dressage
# Equestrian Eventing
# Equestrian Jumping
# Fencing
# Football
# Golf
# Gymnastics Artistic
# Gymnastics Rhythmic
# Handball
# Hockey
# Judo
# Karate
# Marathon Swimming
# Modern Pentathlon
# Rowing
# Rugby
# Sailing
# Shooting
# Skateboarding
# Sport climbing
# Surfing
# Swimming
# Table Tennis
# Taekwondo
# Tennis
# Trampoline
# Triathlon
# Volleyball
# Water Polo
# Weightlifting
# Wrestling Freestyle
# Wrestling Greco-Roman

# %% [markdown]
# - For each summer sport, retrieve all **men’s** and **women’s events** (one level deeper) and print them

# %%
# First try your code for one sport 
r = requests.get('https://www.olympic.org/archery')
s = BeautifulSoup(r.text, 'lxml')

for sp in s.select('section.sport-events ul li'):
    print(sp.text.strip())
# Out:
# individual (Olympic round - 70m) men
# team (Olympic round - 70m) men
# individual (Olympic round - 70m) women
# team (Olympic round - 70m) women
# Mixed team event

# %%
# Then loop through all sports
for sport in soup.select('#summer-sports a'):
    sp = sport['href']
    r = requests.get(f'{www}{sp}')
    s = BeautifulSoup(r.text,'lxml')
    for i in s.select('section.sport-events ul li'):
        print(sport.text.strip(),i.text.strip())
# Out:
# Archery individual (Olympic round - 70m) men
# Archery team (Olympic round - 70m) men
# Archery individual (Olympic round - 70m) women
# Archery team (Olympic round - 70m) women
# Archery Mixed team event
# Artistic Swimming Duet
# Artistic Swimming Team
# Athletics 10000m men
# Athletics 100m men
# Athletics 110m hurdles men
# Athletics 1500m men
# Athletics 200m men
# Athletics 20km race walk men
# Athletics 3000m steeplechase men
# Athletics 400m hurdles men
# Athletics 400m men
# Athletics 4x100m relay men
# Athletics 4x400m relay men
# Athletics 5000m men
# Athletics 50km race walk men
# Athletics 800m men
# Athletics decathlon men
# Athletics discus throw men
# Athletics hammer throw men
# Athletics high jump men
# Athletics javelin throw men
# Athletics long jump men
# Athletics marathon men
# Athletics pole vault men
# Athletics shot put men
# Athletics triple jump men
# Athletics 10000m women
# Athletics 100m hurdles women
# Athletics 100m women
# Athletics 1500m women
# Athletics 200m women
# Athletics 20km race walk women
# Athletics 3000m steeplechase women
# Athletics 400m hurdles women
# Athletics 400m women
# Athletics 4x100m relay women
# Athletics 4x400m relay women
# Athletics 5000m women
# Athletics 800m women
# Athletics discus throw women
# Wrestling Freestyle 96 - 120kg men
# Wrestling Freestyle - 48kg women
# Wrestling Freestyle 48 - 55kg women
# Wrestling Freestyle 55 - 63kg women
# Wrestling Freestyle 63 - 72kg women
# Wrestling Greco-Roman - 55kg men
# Wrestling Greco-Roman 55 - 60kg men
# Wrestling Greco-Roman 60 - 66kg men
# Wrestling Greco-Roman 66 - 74kg men
# Wrestling Greco-Roman 74 - 84kg men
# Wrestling Greco-Roman 84 - 96kg men
# Wrestling Greco-Roman 96 - 120kg men

# %% [markdown]
# - Option: retrieve a list of all **cities** where summer Olympic games have been held together with their **year**, number of **athletes** and number of participating **countries**.

# %%
# Try your code for one O.G.
r = requests.get('https://www.olympic.org/rio-2016')
s = BeautifulSoup(r.text, 'html.parser')
a = s.select_one('div.frame ul')
a = a.select('li')
date = a[0].findAll(text=True)[3].strip()
city = a[1].findAll(text=True)[4].strip()
athletes = a[2].findAll(text=True)[3].strip()
countries = a[3].findAll(text=True)[3].strip()
print(date, city, athletes, countries)
# Out:
# 05 Aug - 21 Aug Brazil 11238 207

# %%
# Then loop through all O.G.'s
www = 'https://www.olympic.org'
r = requests.get(f'{www}/summer-games')
s = BeautifulSoup(r.text, 'lxml')
g = s.select('section.games-section a')

for i in g:
    sg = i.get('href', '')
    r = requests.get(f'{www}{sg}')
    s = BeautifulSoup(r.text, 'html.parser')
    a = s.select_one('div.frame ul')
    a = a.select('li')
    if len(a) > 3:
        date = a[0].findAll(text=True)[3].strip()
        city = a[1].findAll(text=True)[4].strip()
        athletes = a[2].findAll(text=True)[3].strip()
        countries = a[3].findAll(text=True)[3].strip()
        print(i.text.strip(), date, city, athletes, countries)
# Out:
# Paris 2024 26 Jul - 11 Aug France
# Tokyo 2020 23 Jul - 08 Aug Japan
# Rio 2016 05 Aug - 21 Aug Brazil 11238 207
# London 2012 27 Jul - 12 Aug Great Britain 10568 204
# Beijing 2008 08 Aug - 24 Aug People's Republic of China 10942 204
# Athens 2004 13 Aug - 29 Aug Greece 10625 201
# Sydney 2000 15 Sep - 01 Oct Australia 10651 199
# Atlanta 1996 19 Jul - 04 Aug United States of America 10318 197
# Barcelona 1992 25 Jul - 09 Aug Spain 9356 169
# Seoul 1988 17 Sep - 02 Oct Republic of Korea 8397 159
# Los Angeles 1984 28 Jul - 12 Aug United States of America 6829 140
# Moscow 1980 19 Jul - 03 Aug USSR 5179 80
# Montreal 1976 17 Jul - 01 Aug Canada 6084 92
# Munich 1972 26 Aug - 11 Sep Germany 7134 121
# Mexico 1968 12 Oct - 27 Oct Mexico 5516 112
# Tokyo 1964 10 Oct - 24 Oct Japan 5151 93
# Rome 1960 25 Aug - 11 Sep Italy 5338 83
# Melbourne - Stockholm 1956 22 Nov - 08 Dec Australia 3314 72
# Helsinki 1952 19 Jul - 03 Aug Finland 4955 69
# London 1948 29 Jul - 14 Aug Great Britain 4104 59
# Berlin 1936 01 Aug - 16 Aug Germany 3963 49
# Los Angeles 1932 30 Jul - 14 Aug United States of America 1334 37
# Amsterdam 1928 17 May - 12 Aug Netherlands 2883 46
# Paris 1924 04 May - 27 Jul France 3088 44
# Antwerp 1920 20 Apr - 12 Sep Belgium 2622 29
# Stockholm 1912 05 May - 27 Jul Sweden 2407 28
# London 1908 27 Apr - 31 Oct Great Britain 2008 22
# St Louis 1904 01 Jul - 23 Nov United States of America 651 12
# Paris 1900 14 May - 28 Oct France 997 24
# Athens 1896 06 Apr - 15 Apr Greece 241 14

# %%
# Voorbeeldcode om weg te schrijven naar .CSV

# Then loop through all O.G.'s
www = 'https://www.olympic.org'
r = requests.get(f'{www}/summer-games')
s = BeautifulSoup(r.text, 'lxml')
g = s.select('section.games-section a')

# Locatie en naam csv bestand opgeven
outfile = 'test.csv'
# CSV staat nu in directory van dit script

# Headers wegschrijven
# We gebruiken file mode = 'w' ('write')
# Een eventueel bestaand bestand met dezelfde naam wordt overschreven
with open(outfile,"w", newline='', encoding='utf-8') as f:
    writer = csv.writer(f, delimiter = ";",escapechar = "'")
    writer.writerow(['datum','land','n_athletes','n_countries','scrape_date'])

# Nu de loop in
for i in g:
    sg = i.get('href', '')
    r = requests.get(f'{www}{sg}')
    s = BeautifulSoup(r.text, 'html.parser')
    a = s.select_one('div.frame ul')
    a = a.select('li')
    if len(a) > 3:
        date = a[0].findAll(text=True)[3].strip()
        city = a[1].findAll(text=True)[4].strip()
        athletes = a[2].findAll(text=True)[3].strip()
        countries = a[3].findAll(text=True)[3].strip()
        # data samenvoegen in list
        row = [date, city, athletes, countries,dt.datetime.now().strftime("%Y%m%d")]
        print(row)
        # rij wegschrijven naar .csv
        # We gebruiken file mode = 'a' ('append')
        # Aan een eventueel bestaand bestand met dezelfde naam wordt regels toegevoegd (niet overschreven)
        # De headers die we hadden weggeschreven blijven dus behouden
        with open(outfile,"a", newline='', encoding='utf-8') as f:
            writer = csv.writer(f, delimiter = ";",escapechar = "'")
            writer.writerow(row)
# Out:
# ['26 Jul - 11 Aug', 'France', '', '', '20200819']
# ['23 Jul - 08 Aug', 'Japan', '', '', '20200819']
# ['05 Aug - 21 Aug', 'Brazil', '11238', '207', '20200819']
# ['27 Jul - 12 Aug', 'Great Britain', '10568', '204', '20200819']
# ['08 Aug - 24 Aug', "People's Republic of China", '10942', '204', '20200819']
# ['13 Aug - 29 Aug', 'Greece', '10625', '201', '20200819']
# ['15 Sep - 01 Oct', 'Australia', '10651', '199', '20200819']
# ['19 Jul - 04 Aug', 'United States of America', '10318', '197', '20200819']
# ['25 Jul - 09 Aug', 'Spain', '9356', '169', '20200819']
# ['17 Sep - 02 Oct', 'Republic of Korea', '8397', '159', '20200819']
# ['28 Jul - 12 Aug', 'United States of America', '6829', '140', '20200819']
# ['19 Jul - 03 Aug', 'USSR', '5179', '80', '20200819']
# ['17 Jul - 01 Aug', 'Canada', '6084', '92', '20200819']
# ['26 Aug - 11 Sep', 'Germany', '7134', '121', '20200819']
# ['12 Oct - 27 Oct', 'Mexico', '5516', '112', '20200819']
# ['10 Oct - 24 Oct', 'Japan', '5151', '93', '20200819']
# ['25 Aug - 11 Sep', 'Italy', '5338', '83', '20200819']
# ['22 Nov - 08 Dec', 'Australia', '3314', '72', '20200819']
# ['19 Jul - 03 Aug', 'Finland', '4955', '69', '20200819']
# ['29 Jul - 14 Aug', 'Great Britain', '4104', '59', '20200819']
# ['01 Aug - 16 Aug', 'Germany', '3963', '49', '20200819']
# ['30 Jul - 14 Aug', 'United States of America', '1334', '37', '20200819']
# ['17 May - 12 Aug', 'Netherlands', '2883', '46', '20200819']
# ['04 May - 27 Jul', 'France', '3088', '44', '20200819']
# ['20 Apr - 12 Sep', 'Belgium', '2622', '29', '20200819']
# ['05 May - 27 Jul', 'Sweden', '2407', '28', '20200819']
# ['27 Apr - 31 Oct', 'Great Britain', '2008', '22', '20200819']
# ['01 Jul - 23 Nov', 'United States of America', '651', '12', '20200819']
# ['14 May - 28 Oct', 'France', '997', '24', '20200819']
# ['06 Apr - 15 Apr', 'Greece', '241', '14', '20200819']

# %%
# Data bekijken in CSV
with open(outfile,"r",encoding='utf-8') as f:
    reader = csv.reader(f)
    for row in reader:
        print(" ".join(row))
# Out:
# datum;land;n_athletes;n_countries;scrape_date
# 26 Jul - 11 Aug;France;;;20200819
# 23 Jul - 08 Aug;Japan;;;20200819
# 05 Aug - 21 Aug;Brazil;11238;207;20200819
# 27 Jul - 12 Aug;Great Britain;10568;204;20200819
# 08 Aug - 24 Aug;"People's Republic of China";10942;204;20200819
# 13 Aug - 29 Aug;Greece;10625;201;20200819
# 15 Sep - 01 Oct;Australia;10651;199;20200819
# 19 Jul - 04 Aug;United States of America;10318;197;20200819
# 25 Jul - 09 Aug;Spain;9356;169;20200819
# 17 Sep - 02 Oct;Republic of Korea;8397;159;20200819
# 28 Jul - 12 Aug;United States of America;6829;140;20200819
# 19 Jul - 03 Aug;USSR;5179;80;20200819
# 17 Jul - 01 Aug;Canada;6084;92;20200819
# 26 Aug - 11 Sep;Germany;7134;121;20200819
# 12 Oct - 27 Oct;Mexico;5516;112;20200819
# 10 Oct - 24 Oct;Japan;5151;93;20200819
# 25 Aug - 11 Sep;Italy;5338;83;20200819
# 22 Nov - 08 Dec;Australia;3314;72;20200819
# 19 Jul - 03 Aug;Finland;4955;69;20200819
# 29 Jul - 14 Aug;Great Britain;4104;59;20200819
# 01 Aug - 16 Aug;Germany;3963;49;20200819
# 30 Jul - 14 Aug;United States of America;1334;37;20200819
# 17 May - 12 Aug;Netherlands;2883;46;20200819
# 04 May - 27 Jul;France;3088;44;20200819
# 20 Apr - 12 Sep;Belgium;2622;29;20200819
# 05 May - 27 Jul;Sweden;2407;28;20200819
# 27 Apr - 31 Oct;Great Britain;2008;22;20200819
# 01 Jul - 23 Nov;United States of America;651;12;20200819
# 14 May - 28 Oct;France;997;24;20200819
# 06 Apr - 15 Apr;Greece;241;14;20200819
