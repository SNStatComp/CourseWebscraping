# %% [markdown]
# ## Exercise 1: electrical cars

# %%
# Query for all electrical cars:
import requests

r1 = requests.get('https://www.gaspedaal.nl/elektrisch')

print(r1.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#
#
#                     <meta charset="utf-8">
#         <meta http-equiv="X-UA-Compatible" content="IE=edge">
#         <meta name="viewport" content="width=device-width, initial-scale=1">
#         <meta name="csrf-token" content="bhZj7dGZtp8ex8jpGt9GepIpoFOLFFGQhbxWTzJt"/>
#         <meta name="theme-color" content="#ffffff">
#                     <meta name="robots" content="index,follow">
#                 <meta name="viewport" content="width=device-width, initial-scale=1.0">
#                     <meta name="apple-itunes-app" content="app-id=1206862492">
#                             <meta name="google-play-app" content="app-id=nl.gaspedaal.gaspedaal">
#
#                     <link rel="canonical" href="https://www.gaspedaal.nl/elektrisch" />
#
#                     <title>Elektrische auto kopen | Tweedehands elektrische auto - GasPedaal.nl</title>
#
# ...

# %%
# Query for electrical Renaults between 2010 and 2014:

pars = {'bmin': 2010, 'bmax': 2010, 'years': 2}
r2 = requests.get('https://www.gaspedaal.nl/renault/elektrisch?', params=pars)

#print(r2.text)

# %%
# Retrieve the number of occasions from the <h1></h1>:
import re

#print(re.search("occasions gevonden", r2.text))
# TODO
