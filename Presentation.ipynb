# %% [markdown]
# # Examples, course on webscraping
#
# -- * By Olav ten Bosch and Dick Windmeijer *

# %%
# Retrieving the English home page of Statistics Netherlands:
import requests
from bs4 import BeautifulSoup
import time

r1 = requests.get('https://www.cbs.nl/en-gb')

print(r1.status_code, r1.headers['content-type'], r1.encoding)
# Out:
# 200 text/html; charset=utf-8 utf-8

# %%
# Retrieving document:
print(r1.text)
# Out:
# <!DOCTYPE html>
# <html xml:lang="en-GB" lang="en-GB">
# <head>
#     <meta charset="utf-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1" />
#     <meta http-equiv=X-UA-Compatible content="IE=edge" />
#     <title>CBS - Statistics Netherlands</title>
#     <meta name="DCTERMS:identifier" title="XSD.anyURI" content="https://www.cbs.nl/en-gb" />
#     <meta name="DCTERMS.title" content="CBS - Statistics Netherlands" />
#     <meta name="DCTERMS.type" title="OVERHEID.Informatietype" content="webpagina" />
#     <meta name="DCTERMS.language" title="XSD.language" content="en-GB" />
#     <meta name="DCTERMS.authority" title="OVERHEID.Organisatie" content="Statistics Netherlands" />
#     <meta name="DCTERMS.creator" title="OVERHEID.Organisatie" content="Statistics Netherlands" />
#     <meta name="DCTERMS.modified" title="XSD.dateTime" content="16-08-2018T10:41:02" />
#     <meta name="DCTERMS.temporal" content="" />
#     <meta name="DCTERMS.spatial" title="OVERHEID:Koninkrijksdeel" content="The Netherlands" />
#
#     <meta name="description" content="The mission of Statistics Netherlands is to publish reliable and consistent statistical information, that responds to society's demands in this respect." />
#             <meta name="generator" content="CBS Website, Versie 2018.4" />
#
#     <meta name="keywords" content="" />
#     <meta name="robots" content="" />
#     <link rel="alternate" href="https://www.cbs.nl/en-gb" hreflang="en" />
#     <link rel="alternate" href="https://www.cbs.nl/nl-nl" hreflang="nl" />
#     <link rel="shortcut icon" href="https://imagescbs.blob.core.windows.net/cdn/images/cbs_icon.png" type="image/x-icon">
#     <link rel="apple-touch-icon" href="https://imagescbs.blob.core.windows.net/cdn/images/cbs_icon.png">
#
#     <meta name="theme-color" content="#ffffff">
#     <meta name="twitter:card" content="summary_large_image" />
#     <meta name="twitter:site" content="cbs.nl" />
#     <meta name="twitter:site:id" content="statistiekcbs" />
#
#             <meta property="og:image" content="https://www.cbs.nl/Content/images/cbs-ld-logo.png" />
#         <meta property="og:title" content="CBS - Statistics Netherlands" />
#         <meta property="og:type" content="website" />
#         <meta property="og:url" content="https://www.cbs.nl/en-gb" />
#         <meta property="og:locale" content="en_GB">
#         <meta property="og:site_name" content="Statistics Netherlands" />
#         <meta property="og:description" content="The mission of Statistics Netherlands is to publish reliable and consistent statistical information, that responds to society's demands in this respect." />
#
#
#     <!-- Cbs CSS -->
#     <link rel="stylesheet" href="/Content/css/cbs-style.min.css" />
#     <link rel="stylesheet" href="/Content/css/cbs-infographics.min.css" />
#
#             <script type="application/ld+json">
#             {
#   "@context": "http://schema.org",
#
#   "@graph":[
#   {
#   "@type": "WebSite",
#   "url": "https://www.cbs.nl/",
#   "potentialAction": {
#     "@type": "SearchAction",
#     "target": "https://www.cbs.nl/nl-nl/zoeken/?query={search_term_string}",
#     "query-input": "required name=search_term_string"
#   }
#   },
#   {
#   "@type": "Organization",
#   "name": "Centraal Bureau voor de Statistiek",
#   "alternateName": ["CBS","Statistics Netherlands"],
#   "type": "GovernmentOrganization",
#   "url": "https://www.cbs.nl",
#   "logo": "https://www.cbs.nl/Content/images/cbs-ld-logo.png",
#   "address": {
#     "type": "PostalAddress",
#     "addressCountry": "Nederland",
#     "addressLocality": "Den Haag",
#     "addressRegion": "Zuid-Holland",
#     "postalCode": "2492 JP",
#     "streetAddress": "Henri Faasdreef 312, Den Haag"
#   },
#   "contactPoint": {
#     "type": "ContactPoint",
#     "areaServed": "NL",
#     "availableLanguage": [
#       "Dutch",
#       "English"
#     ],
#     "contactType": "customer service",
#     "email": "https://www.cbs.nl/nl-nl/over-ons/contact/contactformulier",
#     "hoursAvailable": "Mo,Tu,We,Th,Fr 08:30-17:30",
#     "name": "Infoservice",
#     "productSupported": "cbs.nl",
#     "telephone": "+31 088 570 7070",
#     "url": "https://www.cbs.nl/nl-nl/over-ons/contact/infoservice"
#   },
#   "sameAs": [
#     "https://www.facebook.com/statistiekcbs",
#     "https://www.twitter.com/statistiekcbs",
#     "https://www.wikidata.org/wiki/Q167086",
#     "https://g.co/kg/m/024xlr",
#     "https://nl.wikipedia.org/wiki/Centraal_Bureau_voor_de_Statistiek",
#     "https://www.youtube.com/user/statistiekcbs",
#     "https://www.linkedin.com/company/centraal-bureau-voor-de-statistiek"
#   ]
# }
#  ]
# }
#         </script>
#
#         <script>
#             var highchartsLogo = '/-/media/cbs/Infographics/highcharts-logo.png';
#             window.Highcharts = undefined;
#         </script>
#         <script src="//code.jquery.com/jquery-2.2.4.min.js"></script>
#     <script src="//f1-na.readspeaker.com/script/37/webReader/webReader.js?pids=wr" type="text/javascript"></script>
#
#     <!--[if lt IE 9]>
#         <script src="/Content/js/libs/bootstrap/html5shiv.min.js"></script>
#         <script src="/Content/js/libs/bootstrap/respond.min.js"></script>
#     <![endif]-->
# </head>
# <body>
#         <a class="sr-only sr-only-focusable hidden-xs" href="#main">Skip to main content</a>
# <header class="cbs-header-mainmenu cbs-header-HoofdMenu">
# 	<div class="inner">
# 		<div class="container group">
# 			<div class="navbar-header">
# 				<button type="button" class="navbar-toggle collapsed" data-toggle="collapse" data-target=".nav-mainmenu" aria-expanded="false" aria-controls="nav-mainmenu">
# 					<span class="sr-only">Change navigation</span>
# 					<span class="icon-bar"></span>
# 					<span class="icon-bar"></span>
# 					<span class="icon-bar"></span>
# 				</button>
# 			</div>
#
# 			<div class="logo">
# 				<a href="/en-gb" aria-label="CBS home"><img src="/Content/images/cbs-brand.svg" alt="Statistics Netherlands"/></a>
# 			</div>
#
# 			<nav id="nav-mainmenu" role="navigation" class="menu collapse navbar-collapse nav-mainmenu">
#
# 	<ul role="menubar">
#
# 				<li role="menuitem" class="" aria-haspopup="true">
# 					<a href="/en-gb/labour-and-income">Labour and income</a>
#
# 						<ul role="menu" class="submenu" aria-haspopup="true">
#
# 								<li role="menuitem"><a href="/en-gb/labour-and-income/labour-and-social-security">Labour and social security</a></li>
# 								<li role="menuitem"><a href="/en-gb/labour-and-income/income-and-spending">Income and spending</a></li>
# 						</ul>
# 				</li>
# 				<li role="menuitem" class="" aria-haspopup="true">
# 					<a href="/en-gb/economy">Economy</a>
#
# 						<ul role="menu" class="submenu" aria-haspopup="true">
#
# 								<li role="menuitem"><a href="/en-gb/economy/enterprises">Enterprises</a></li>
# 								<li role="menuitem"><a href="/en-gb/economy/construction-and-housing">Construction and housing</a></li>
# 								<li role="menuitem"><a href="/en-gb/economy/financial-and-business-services">Financial and business services</a></li>
# 								<li role="menuitem"><a href="/en-gb/economy/trade-hotels-and-restaurants">Trade, hotels and restaurants</a></li>
# 								<li role="menuitem"><a href="/en-gb/economy/manufacturing-and-energy">Manufacturing and energy</a></li>
# 								<li role="menuitem"><a href="/en-gb/economy/international-trade">International trade</a></li>
# 								<li role="menuitem"><a href="/en-gb/economy/agriculture">Agriculture</a></li>
# 								<li role="menuitem"><a href="/en-gb/economy/macroeconomics">Macroeconomics</a></li>
# 								<li role="menuitem"><a href="/en-gb/economy/government-and-politics">Government and politics</a></li>
# 								<li role="menuitem"><a href="/en-gb/economy/prices">Prices</a></li>
# 						</ul>
# 				</li>
# 				<li role="menuitem" class="" aria-haspopup="true">
# 					<a href="/en-gb/society">Society</a>
#
# 						<ul role="menu" class="submenu" aria-haspopup="true">
#
# 								<li role="menuitem"><a href="/en-gb/society/population">Population</a></li>
# 								<li role="menuitem"><a href="/en-gb/society/health-and-welfare">Health and welfare</a></li>
# 								<li role="menuitem"><a href="/en-gb/society/nature-and-environment">Nature and environment</a></li>
# 								<li role="menuitem"><a href="/en-gb/society/education">Education</a></li>
# 								<li role="menuitem"><a href="/en-gb/society/security-and-justice">Security and justice</a></li>
# 								<li role="menuitem"><a href="/en-gb/society/traffic-and-transport">Traffic and transport</a></li>
# 								<li role="menuitem"><a href="/en-gb/society/leisure-and-culture">Leisure and culture</a></li>
# 						</ul>
# 				</li>
# 				<li role="menuitem" class="" aria-haspopup="false"><a href="/en-gb/dossier/regional-statistics">Regional</a></li>
# 				<li role="menuitem" class="" aria-haspopup="false"><a href="/en-gb/about-us/cbs-corporate-news">Corporate</a></li>
# 				<li role="menuitem" class="" aria-haspopup="true">
# 					<a href="/en-gb/figures">Figures</a>
#
# 				</li>
#
# 			<li role="menuitem" class="visible-xs-block" aria-haspopup="false"><a href="/en-gb/our-services">Services</a></li>
# 			<li role="menuitem" class="visible-xs-block" aria-haspopup="false"><a href="/en-gb/our-services/blaise-software">Blaise software</a></li>
# 			<li role="menuitem" class="visible-xs-block" aria-haspopup="false"><a href="/en-gb/about-us">About us</a></li>
#
# 		<li role="menuitem" class="visible-xs-block" aria-haspopup="false"><a href="/nl-nl">Nederlands</a></li>
# 	</ul>
#
# 			</nav>
#
# 			<div class="cbs-header-systemlinks navbar-right hidden-xs">
# 				<a href="/nl-nl">Nederlands</a>
# 			</div>
#
# 			<div class="cbs-header-search navbar-right">
# 				<a class="no-js-search" href="/en-gb/search" aria-label="Search">
# 					<span class="fa fa-search"></span><span class="visually-hidden">Search</span>
# 				</a>
# 			</div>
# 		</div>
# 	</div>
#
# <form action="/api/sitecore/Search/SearchAndRedirect" class="quick-search" method="post">		<div class="overlay"></div>
# 		<div class="searchbox">
# 			<div class="searchform form-group has-feedback">
# 				<input type="hidden" name="fhController" value="SearchController">
# 				<input type="hidden" name="fhAction" value="SearchAndRedirect">
# 				<input type="hidden" name="searchPageUrl" value="/en-gb/search" />
# 				<label for="quicksearchqueryinput" class="visually-hidden">Search</label>
# 				<div class="searchalign">
# 					<input id="quicksearchqueryinput" name="searchqueryinput" type="text" placeholder="Search">
# 					<button type="submit" class="searchbutton" aria-label="Search"><span class="fa fa-search"></span><span class="visually-hidden">Search</span></button>
# 				</div>
# 			</div>
# 		</div>
# </form>
# </header>
#
#
# <main id="main" role="main" class="container container-content container-HoofdMenu homepage-layout no-js" tabindex="-1">
# 	<div class="row">
# 		<h1 class="visually-hidden">Cbs Home</h1>
# 		<section class="col-lg-9 col-md-12 col-sm-12 col-xs-12">
# 	<div class="teaser-container">
# 		<a href="/en-gb/news/2018/39/manufacturing-output-prices-over-5-percent-up">
# 			<figure><img src="https://imagescbs.blob.core.windows.net/images/675541622b67397852386737516b6e69586c747764673d3d/900x450.jpg" alt="" width="900" class="img-responsive" /></figure>
# 				<h2 style="background-color:#0058b8;" class="bottom">Manufacturing output prices over 5 percent up </h2>
# 		</a>
# 	</div>
# </section><section class="col-lg-9 col-md-8 col-sm-8 col-xs-12">
#
#             <h2 class="visually-hidden">Recent news</h2>
#     <div class="multi-rows row">
#             <div class="col-lg-4 col-md-6 col-sm-6 col-xs-12">
#                 <div class="thumbnail">
#                     <a href="/en-gb/news/2018/39/producer-confidence-hardly-changes">
#
#                         <div class="cbs-image-container">
#
#
#         <img class="img-responsive" src="https://imagescbs.blob.core.windows.net/images/494b3979793463696a57796d4c4d373146536d3275513d3d/294x196.jpg" alt="" />
#
# </div>
#
#
#
#                         <div class="caption">
#                             <h3>Producer confidence hardly changes</h3>
#                                 <p>27/09/2018 15:00</p>
#                         </div>
#                     </a>
#                 </div>
#             </div>            <div class="col-lg-4 col-md-6 col-sm-6 col-xs-12">
#                 <div class="thumbnail">
#                     <a href="/en-gb/news/2018/39/1-5-of-manufacturing-exports-are-carry-along-trade">
#
#                         <div class="cbs-image-container">
#
#
#         <img class="img-responsive" src="https://imagescbs.blob.core.windows.net/images/6c56734c4f6347676c41334264397533526c435277413d3d/294x196.jpg" alt="" />
#
# </div>
#
#
#
#                         <div class="caption">
#                             <h3>1/5 of manufacturing exports are carry-along trade</h3>
#                                 <p>27/09/2018 15:00</p>
#                         </div>
#                     </a>
#                 </div>
#             </div>            <div class="col-lg-4 col-md-6 col-sm-6 col-xs-12">
#                 <div class="thumbnail">
#                     <a href="/en-gb/news/2018/37/1-in-5-obese-adults-satisfied-with-body-weight">
#
#                         <div class="cbs-image-container">
#
#
#         <img class="img-responsive" src="https://imagescbs.blob.core.windows.net/images/436955356d4546506d7444484933414f6652615030673d3d/294x196.jpg" alt="" />
#
# </div>
#
#
#
#                         <div class="caption">
#                             <h3>1 in 5 obese adults satisfied with body weight</h3>
#                                 <p>25/09/2018 15:00</p>
#                         </div>
#                     </a>
#                 </div>
#             </div>            <div class="col-lg-4 col-md-6 col-sm-6 col-xs-12">
#                 <div class="thumbnail">
#                     <a href="/en-gb/news/2018/38/budget-surplus-up-to-1-9-percent-of-gdp-in-mid-2018">
#
#                         <div class="cbs-image-container">
#
#
#         <img class="img-responsive" src="https://imagescbs.blob.core.windows.net/images/49656459464e76623744424233336573386b564979673d3d/294x196.jpg" alt="" />
#
# </div>
#
#
#
#                         <div class="caption">
#                             <h3>Budget surplus up to 1.9 percent of GDP in mid-2018</h3>
#                                 <p>24/09/2018 15:00</p>
#                         </div>
#                     </a>
#                 </div>
#             </div>            <div class="col-lg-4 col-md-6 col-sm-6 col-xs-12">
#                 <div class="thumbnail">
#                     <a href="/en-gb/news/2018/38/house-prices-over-9-percent-higher-in-august">
#
#                         <div class="cbs-image-container">
#
#
#         <img class="img-responsive" src="https://imagescbs.blob.core.windows.net/images/66766e67494f594976314f4772432f67346f637968673d3d/294x196.jpg" alt="" />
#
# </div>
#
#
#
#                         <div class="caption">
#                             <h3>House prices over 9 percent higher in August</h3>
#                                 <p>24/09/2018 09:43</p>
#                         </div>
#                     </a>
#                 </div>
#             </div>            <div class="col-lg-4 col-md-6 col-sm-6 col-xs-12">
#                 <div class="thumbnail">
#                     <a href="/en-gb/news/2018/38/gdp-growth-rate-0-8-percent-in-q2-2018">
#
#                         <div class="cbs-image-container">
#
#
#         <img class="img-responsive" src="https://imagescbs.blob.core.windows.net/images/327a4f3262336e616f535a76744c68704162796870513d3d/294x196.jpg" alt="" />
#
# </div>
#
#
#
#                         <div class="caption">
#                             <h3>GDP growth rate 0.8 percent in Q2 2018</h3>
#                                 <p>21/09/2018 15:00</p>
#                         </div>
#                     </a>
#                 </div>
#             </div>            <div class="col-lg-4 col-md-6 col-sm-6 col-xs-12">
#                 <div class="thumbnail">
#                     <a href="/en-gb/news/2018/38/mobile-phones-less-often-secure-than-computers">
#
#                         <div class="cbs-image-container">
#
#
#         <img class="img-responsive" src="https://imagescbs.blob.core.windows.net/images/5072456c73727272366a59473576684c6b4e746778413d3d/294x196.jpg" alt="" />
#
# </div>
#
#
#
#                         <div class="caption">
#                             <h3>Mobile phones less often secure than computers</h3>
#                                 <p>21/09/2018 15:00</p>
#                         </div>
#                     </a>
#                 </div>
#             </div>            <div class="col-lg-4 col-md-6 col-sm-6 col-xs-12">
#                 <div class="thumbnail">
#                     <a href="/en-gb/news/2018/38/economic-situation-unchanged">
#
#                         <div class="cbs-image-container">
#
#
#         <img class="img-responsive" src="https://imagescbs.blob.core.windows.net/images/514b6136454f765061495a75493851396e73494a66773d3d/294x196.jpg" alt="" />
#
# </div>
#
#
#
#                         <div class="caption">
#                             <h3>Economic situation unchanged</h3>
#                                 <p>21/09/2018 15:00</p>
#                         </div>
#                     </a>
#                 </div>
#             </div>            <div class="col-lg-4 col-md-6 col-sm-6 col-xs-12">
#                 <div class="thumbnail">
#                     <a href="/en-gb/news/2018/38/investments-over-6-percent-up-in-july">
#
#                         <div class="cbs-image-container">
#
#
#         <img class="img-responsive" src="https://imagescbs.blob.core.windows.net/images/4259485664513955316977314e6c31636953734836673d3d/294x196.jpg" alt="" />
#
# </div>
#
#
#
#                         <div class="caption">
#                             <h3>Investments over 6 percent up in July</h3>
#                                 <p>21/09/2018 15:00</p>
#                         </div>
#                     </a>
#                 </div>
#             </div>            <div class="col-lg-4 col-md-6 col-sm-6 col-xs-12">
#                 <div class="thumbnail">
#                     <a href="/en-gb/news/2018/38/employment-rate-virtually-the-same-for-six-months">
#
#                         <div class="cbs-image-container">
#
#
#         <img class="img-responsive" src="https://imagescbs.blob.core.windows.net/images/31664456474d6430656e2b324778652b2b504f6942673d3d/294x196.jpg" alt="" />
#
# </div>
#
#
#
#                         <div class="caption">
#                             <h3>Employment rate virtually the same for six months</h3>
#                                 <p>20/09/2018 15:00</p>
#                         </div>
#                     </a>
#                 </div>
#             </div>            <div class="col-lg-4 col-md-6 col-sm-6 col-xs-12">
#                 <div class="thumbnail">
#                     <a href="/en-gb/news/2018/38/household-consumption-nearly-3-percent-up-in-july">
#
#                         <div class="cbs-image-container">
#
#
#         <img class="img-responsive" src="https://imagescbs.blob.core.windows.net/images/56713675416c5a67766347757a534e683473676850673d3d/294x196.jpg" alt="" />
#
# </div>
#
#
#
#                         <div class="caption">
#                             <h3>Household consumption nearly 3 percent up in July</h3>
#                                 <p>20/09/2018 15:00</p>
#                         </div>
#                     </a>
#                 </div>
#             </div>            </div>
# </section>
#
# 		<section id="aside-main" class="col-lg-3 col-md-4 col-sm-4 col-xs-12">
# 			<aside role="complementary" class="sidebar-aqua col-xs-12 aside-override">
# 	<div class="aside-content">
# 		<h2>Featured</h2>
# 				<a href="/en-gb/publication/2018/39/internationalisation-monitor-2018-third-quarter">
# 					<h3>Internationalisation Monitor 2018, third quarter</h3>
# 					<p class="type"></p>
# 				</a>
# 				<a href="https://longreads.cbs.nl/trends18-eng/">
# 					<h3>Trends in the Netherlands 2018</h3>
# 					<p class="type"></p>
# 				</a>
# 				<a href="/en-gb/publication/2018/10/the-sdgs-the-situation-for-the-netherlands">
# 					<h3>The SDGs: the situation for the Netherlands</h3>
# 					<p class="type"></p>
# 				</a>
# 	</div>
# </aside>    <aside role="complementary" class="sidebar-darkblue col-xs-12 aside-override">
#         <div class="aside-content">
#             <h2>CBS video</h2>
# <div class="embed-responsive embed-responsive-16by9"><iframe class="embed-responsive-item" title="YouTube video id O8tdu1KuTRA" src="https://www.youtube.com/embed/O8tdu1KuTRA?rel=0&wmode=transparent&showinfo=0" allowfullscreen></iframe></div>                            <h3 class="title">The Netherlands 10 years after Lehman Brothers (English subtitles available)</h3>        </div>
#     </aside>
# <aside role="complementary" class="sidebar-purple col-xs-12 aside-override">
#     <div class="aside-content">
#             <a href="/en-gb/publication-calendar">
#                 <h2>Expected<span class="fa fa-calendar" title="Publicatiekalender"></span></h2>
#             </a>
#                         <div class="pub-toggle cursor-pointer">
#                     <h3>Bilateral trade with the UK</h3>
#                     <p class="date">03/10/2018 15:00</p>
#                     <p class="pub-description">
#                         How did exports to the United Kingdom develop in the first 7 months of 2018?
#
#
#                             <span class="embargo-event">Available under <a href="https://www.cbs.nl/en-gb/about-us/organisation/publication-policy">embargo</a></span>
#                     </p>
#                 </div>
#                 <div class="pub-toggle cursor-pointer">
#                     <h3>Neighbourhood nuisance on Saba and St Eustatius</h3>
#                     <p class="date">04/10/2018 00:00</p>
#                     <p class="pub-description">
#                         What is the percentage share of residents on St Eustatius who encounter neighbourhood nuisance, and what about Saba?
#
#
#                             <span class="embargo-event">Available under <a href="https://www.cbs.nl/en-gb/about-us/organisation/publication-policy">embargo</a></span>
#                     </p>
#                 </div>
#                 <div class="pub-toggle cursor-pointer">
#                     <h3>Consumer prices</h3>
#                     <p class="date">04/10/2018 15:00</p>
#                     <p class="pub-description">
#                         Price developments for the month of September.
#
#
#                     </p>
#                 </div>
#                 <div class="pub-toggle cursor-pointer">
#                     <h3>Young people's participation in society</h3>
#                     <p class="date">05/10/2018 15:00</p>
#                     <p class="pub-description">
#                         To what degree are young people socially involved, are there any differences among age groups?
#
#
#                             <span class="embargo-event">Available under <a href="https://www.cbs.nl/en-gb/about-us/organisation/publication-policy">embargo</a></span>
#                     </p>
#                 </div>
# 	</div>
# </aside><aside role="complementary" class="sidebar-twitter col-xs-12 aside-override hidden-xs">
# 	<div class="aside-content">
#
# 		<a href="https://twitter.com/statisticscbs">
# 			<h2>
# 				Twitter
#
# 				<span class="fa fa-twitter" title=""></span>
# 			</h2>
# 		</a>
#
# 		<a class="twitter-timeline hide"
# 		   data-widget-id="710405451385540608"
# 		   href="https://twitter.com/statisticscbs?ref_src=twsrc%5Etfw"
# 		   title="Twitter"
# 		   data-chrome="nofooter noborders transparent noheader"></a>
# 	</div>
# </aside>
# <script async="" src="//platform.twitter.com/widgets.js" charset="utf-8"></script>
# 		</section>
# 	</div>
# </main><div class="footer-container">
# 	<footer role="contentinfo" class="container">
# 		<div class="row multi-rows">
# 				<div class="col-lg-3 col-md-3 col-sm-3 col-xs-12">
# 						<p class="title"><a href="/en-gb/our-services">Services</a></p>
#                     <ul>
#                             <li>
#                                 <a href="/en-gb/our-services/customised-services-microdata">Customised services & microdata</a>
#                             </li>
#                             <li>
#                                 <a href="/en-gb/our-services/unique-collaboration-for-big-data-research">Center for Big Data Statistics</a>
#                             </li>
#                             <li>
#                                 <a href="/en-gb/our-services/innovation">Innovation</a>
#                             </li>
#                             <li>
#                                 <a href="/en-gb/our-services/methods">Methodology</a>
#                             </li>
#                             <li>
#                                 <a href="/en-gb/our-services/print-publications">Print publications</a>
#                             </li>
#                             <li>
#                                 <a href="/en-gb/our-services/open-data">Open Data</a>
#                             </li>
#                             <li>
#                                 <a href="/en-gb/visualization/2016/12/calculation-of-rent-increase--private-housing-sector--">Calculation of rent increase</a>
#                             </li>
#                             <li>
#                                 <a href="https://opendata.cbs.nl/statline/#/CBS/en/" target="_blank">Figures/StatLine</a>
#                             </li>
#                             <li>
#                                 <a href="/en-gb/our-services/archive">Archive</a>
#                             </li>
#                     </ul>
# 				</div>
# 				<div class="col-lg-3 col-md-3 col-sm-3 col-xs-12">
# 						<p class="title"><a href="/en-gb/our-services/blaise-software">Blaise software</a></p>
#                     <ul>
#                             <li>
#                                 <a href="http://www.blaise.com/products/general-information">Products</a>
#                             </li>
#                             <li>
#                                 <a href="https://www.blaise.com/company/contact-us">Pricing</a>
#                             </li>
#                             <li>
#                                 <a href="http://blaise.com/support/general-info">Support</a>
#                             </li>
#                             <li>
#                                 <a href="http://www.blaise.com/community/blaise-user-pages">Community</a>
#                             </li>
#                     </ul>
# 				</div>
# 				<div class="col-lg-3 col-md-3 col-sm-3 col-xs-12">
# 						<p class="title"><a href="/en-gb/about-us">About us</a></p>
#                     <ul>
#                             <li>
#                                 <a href="/en-gb/about-us/contact">Contact</a>
#                             </li>
#                             <li>
#                                 <a href="/en-gb/about-us/organisation">Organisation</a>
#                             </li>
#                             <li>
#                                 <a href="/en-gb/about-us/contact/press-office">Press</a>
#                             </li>
#                             <li>
#                                 <a href="/en-gb/about-us/careers-at-cbs">Careers at CBS</a>
#                             </li>
#                             <li>
#                                 <a href="/en-gb/about-us/website">Website</a>
#                             </li>
#                             <li>
#                                 <a href="/en-gb/sitemap">Sitemap</a>
#                             </li>
#                     </ul>
# 				</div>
# 				<div class="col-lg-3 col-md-3 col-sm-3 col-xs-12">
# 						<p class="title"><a href="/en-gb/follow-us">Follow us</a></p>
#                     <ul>
#                             <li>
#                                 <a href="/en-gb/publication-calendar">Publication planning</a>
#                             </li>
#                             <li>
#                                 <a href="https://www.facebook.com/statisticscbs/" target="_blank">Facebook</a>
#                             </li>
#                             <li>
#                                 <a href="https://www.youtube.com/playlist?list=PLekr62u_EkPwIlf3Q1OeJr0neCuOgzOhT" target="_blank">YouTube</a>
#                             </li>
#                             <li>
#                                 <a href="https://twitter.com/StatisticsCBS">Twitter</a>
#                             </li>
#                             <li>
#                                 <a href="/en-gb/rss-feeds">RSS feeds</a>
#                             </li>
#                             <li>
#                                 <a href="/en-gb/newsletters">Newsletters</a>
#                             </li>
#                     </ul>
# 				</div>
# 		</div>
# 	</footer>
# </div><script>var cbsSettings; (function (cbsSettings) { cbsSettings.dictItems = [{"Key":"lastmodified","Phrase":""},{"Key":"publicationdate","Phrase":""},{"Key":"today","Phrase":"today"},{"Key":"tomorrow","Phrase":"tomorrow"},{"Key":"yesterday","Phrase":"yesterday"},{"Key":"days","Phrase":"{0} days ago"},{"Key":"hour","Phrase":"1 hour ago"},{"Key":"hours","Phrase":"{0} hours ago"},{"Key":"minute","Phrase":"1 minute ago"},{"Key":"minutes","Phrase":"{0} minutes ago"}], cbsSettings.search = {enableAutocomplete: true} })(cbsSettings || (cbsSettings = {}));</script>                <script src="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/js/bootstrap.min.js" integrity="sha384-Tc5IQib027qvyjSMfHjOMaLkfuWVxZxUPnCJA7l2mCWNIpG9mGCD8wGNIcPD7Txa" crossorigin="anonymous"></script>
#                 <script src="https://code.highcharts.com/5.0.14/highcharts.js"></script>
#                 <script src="https://code.highcharts.com/maps/6.0.7/modules/map.js"></script>
#                 <script src="https://code.highcharts.com/5.0.14/modules/data.js"></script>
#                 <script src="https://code.highcharts.com/5.0.14/highcharts-more.js"></script>
#                 <script src="https://code.highcharts.com/5.0.14/modules/exporting.js"></script>
#                 <script src="https://code.highcharts.com/5.0.14/modules/offline-exporting.js"></script>
#                 <script src="https://code.highcharts.com/5.0.14/modules/broken-axis.js"></script>
#             <script src="https://imagescbs.blob.core.windows.net/cdn/export-csv.min.js"></script>
#             <script src="/Content/js/libs/highcharts/latest/modules/grouped-categories.min.js"></script>
#             <script src="/Content/js/libs/jquery-lib.min.js"></script>
#             <script src="/Content/js/cbs/cbs.min.js"></script>
#             <script src="/Content/js/libs/wffm.custom.js"></script>
# <script>
# 		(function (i, s, o, g, r, a, m) {
# 			i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function () {
# 				(i[r].q = i[r].q || []).push(arguments)
# 			}, i[r].l = 1 * new Date(); a = s.createElement(o),
# 			m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m)
# 		})(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#
# 		ga('create', 'UA-4397804-1', 'auto');
# 		ga('set', 'anonymizeIp', true);
# 		ga('set', 'forceSSL', true);
# 		ga('send', 'pageview');
#
# 		if (typeof jQuery != 'undefined') {
# 			jQuery(document).ready(function ($) {
# 				var filetypes = /\.(zip*|pdf*|doc*|xls*|pps*|ppt*|epub*)/i;
# 				jQuery('a').each(function () {
# 					var href = jQuery(this).attr('href');
# 					var target = jQuery(this).attr('target');
# 					var text = jQuery(this).text();
# 					var thisEvent = jQuery(this).attr('onclick');
# 					if (href) {
# 						if (href.match(filetypes)) {
# 							jQuery(this).click(function (event) {
# 								if (event.target.href.match(/:\/\/download\.cbs\.nl\//i)) {
# 									event.preventDefault();
# 									var extension = String((/[.]/.exec(href)) ? /[^.]+$/.exec(href) : undefined);
# 									ga('send', {
# 										hitType: 'event',
# 										eventCategory: 'Downloads',
# 										eventAction: extension.toLowerCase(),
# 										eventLabel: event.target.href
# 									});
# 									setTimeout(function () {
# 										eval(thisEvent);
# 										window.open(event.target.href, (!target ? '_self' : target));
# 									}, 200);
# 									return false;
# 								}
# 							});
# 						}
# 					}
# 				});
# 			});
# 		}
# 	</script>
# 	<script type="text/javascript">
# 		/*<![CDATA[*/
# 		(function () {
# 			var sz = document.createElement('script'); sz.type = 'text/javascript'; sz.async = true;
# 			sz.src = '//siteimproveanalytics.com/js/siteanalyze_6009242.js';
# 			var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(sz, s);
# 		})();
# 		/*]]>*/
# 	</script>
# 	<style>
# 		.thumbnail .caption h3 {
# 			font-size: 1.15rem;
# 		}
#
# 		@media (max-width: 767px) {
# 			.thumbnail .caption h3 {
# 				font-size: 1rem;
# 			}
# 		}
#
# 		.panel-title {
# 			font-size: 1rem;
# 		}
# 	</style></body>
# </html>

# %%
# Issue an request with parameters:

pars = {'products': 2, 'years': 2}
r2 = requests.get('http://testing-ground.scraping.pro/table?', params=pars)
        
print(r2.url)
# Out:
# http://testing-ground.scraping.pro/table?products=2&years=2

# %%
# Retrieving document:
print(r2.text)
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js"> <!--<![endif]-->
#     <head>
#         <meta charset="utf-8">
#         <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
#         <title>Web Scraper Testing Ground</title>
#         <meta name="description" content="">
#         <meta name="viewport" content="width=device-width">
#         <link rel="stylesheet" href="/css/normalize.css">
#         <link rel="stylesheet" href="/css/main.css">
#         <script src="/js/vendor/modernizr-2.6.1.min.js"></script>
#         <script src="/js/vendor/jquery-1.9.1.min.js"></script>
#         <script src="/js/vendor/jquery-ui-1.10.2.min.js"></script>
#         <script src="/js/plugins.js"></script>
#         <script src="/js/main.js"></script>
#
#         <link rel="stylesheet" href="/css/QapTcha.jquery.css" />
#         <script src="/js/QapTcha.jquery.js"></script>
#
#         <link rel="stylesheet" href="/fancy-captcha/captcha.css" />
#         <script src="/fancy-captcha/jquery.captcha.js"></script>
#
#     </head>
#     <body>
# 		<script type="text/javascript">
#
# 		  var _gaq = _gaq || [];
# 		  _gaq.push(['_setAccount', 'UA-4436411-8']);
# 		  _gaq.push(['_setDomainName', 'extract-web-data.com']);
# 		  _gaq.push(['_trackPageview']);
#
# 		  (function() {
# 		    var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
# 		    ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
# 		    var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
# 		  })();
#
# 		</script>
#         <!--[if lt IE 7]>
#             <p class="chromeframe">You are using an outdated browser. <a href="http://browsehappy.com/">Upgrade your browser today</a> or <a href="http://www.google.com/chromeframe/?redirect=true">install Google Chrome Frame</a> to better experience this site.</p>
#         <![endif]-->
#         <div id="topbar"></div>
# 		<a href="/" style="text-decoration: none">
# 		    <div id="title">WEB SCRAPER TESTING GROUND</div>
# 		    <div id="logo"></div>
# 		</a>
# 		<div id="content"><h1>TABLE REPORT</h1>
# <div id="caseinfo">Suppose you need to scrape a financial report organized as a table. This test checks the scraper's ability to:
# <ol>
# 	<li>Support tables with indefinite number of rows and columns</li>
# 	<li>Tolerate merged columns and rows</li>
# 	<li>Parse currency format</li>
# 	<li>Extract only a certain year</li>
# </ol>
# To change the table you may use the following parameters:
# <ul>
# 	<li><b>products</b> - number of product columns (from 1 to 50)</li>
# 	<li><b>years</b> - number of year sections in the report</li>
# 	<li><b>quarters</b> - number of quarters in the last year</li>
# </ul>
# There should be a one year section with a merged column (for Product 3), and if more than one year are shown, there should be one or more merged cells in some quarter rows (for Products 1 and 2). All merged cells in the report contain a hyphen only.
# <p>For testing, you may use the following sample links. The scraper should sufficiently scrape all data from the reports using the same project:
# <ul>
# <li><a href="/table?products=1&years=1&quarters=1">1 product, 1 quarter</a></li>
# <li><a href="/table?products=4&years=3&quarters=2">4 products, 2.5 years</a></li>
# <li><a href="/table?products=10&years=10&quarters=4">10 products, 10 years</a></li>
# </ul>
# </p>
# </div>
#
# <div id="case_table">
# <table cellpadding="5px" cellspacing="5px" border="1">
# 	<thead>
# 		<tr>
# 			<th width="120px" rowspan="2">Quarter</th>
# 			<th colspan='2'>Product 1</th><th colspan='2'>Product 2</th>			<th width="100px" rowspan="2">Total Amount</th>
# 		</tr>
# 		<tr>
# 			<th width="100px">Items</th><th width="100px">Amount</th><th width="100px">Items</th><th width="100px">Amount</th>		</tr>
# 	</thead>
# 	<tbody>
# <tr><td colspan='6' align='center' style='font-weight: bold'><center>2000</center></td></tr><tr><td>Q1</td><td style='background:#FEE' colspan='2'><center>-</center></td><td>49</td><td>$9,746.10</td><td>$9,746.10</td></tr><tr><td>Q2</td><td>61</td><td>$12,132.90</td><td>68</td><td>$13,525.20</td><td>$25,658.10</td></tr><tr><td>Q3</td><td>75</td><td>$14,917.50</td><td>77</td><td>$15,315.30</td><td>$30,232.80</td></tr><tr><td>Q4</td><td>78</td><td>$15,514.20</td><td>76</td><td>$15,116.40</td><td>$30,630.60</td></tr><tr><td><b>Total for 2000</b></td><td colspan='5'><b>$138,832.20</b></td></tr><tr><td colspan='6' style='background:#EEE'></td></tr><tr><td colspan='6' align='center' style='font-weight: bold'><center>2001</center></td></tr><tr><td>Q1</td><td>70</td><td>$13,923.00</td><td>64</td><td>$12,729.60</td><td>$26,652.60</td></tr><tr><td>Q2</td><td>53</td><td>$10,541.70</td><td>43</td><td>$8,552.70</td><td>$19,094.40</td></tr><tr><td>Q3</td><td>28</td><td>$5,569.20</td><td>17</td><td>$3,381.30</td><td>$8,950.50</td></tr><tr><td>Q4</td><td>1</td><td>$198.90</td><td>12</td><td>$2,386.80</td><td>$2,585.70</td></tr><tr><td><b>Total for 2001</b></td><td colspan='5'><b>$87,516.00</b></td></tr><tr><td colspan='6' style='background:#EEE'></td></tr>	</tbody>
# </table>
# <br/><br/><br/>
# </div>
#
# 		</div>
#     </body>
# </html>

# %%
# Retrieving English home page of Statistics Netherlands:
r3 = requests.get('https://www.cbs.nl/en-gb')
print(r3.text)
# Out:
# <!DOCTYPE html>
# <html xml:lang="en-GB" lang="en-GB">
# <head>
#     <meta charset="utf-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1" />
#     <meta http-equiv=X-UA-Compatible content="IE=edge" />
#     <title>CBS - Statistics Netherlands</title>
#     <meta name="DCTERMS:identifier" title="XSD.anyURI" content="https://www.cbs.nl/en-gb" />
#     <meta name="DCTERMS.title" content="CBS - Statistics Netherlands" />
#     <meta name="DCTERMS.type" title="OVERHEID.Informatietype" content="webpagina" />
#     <meta name="DCTERMS.language" title="XSD.language" content="en-GB" />
#     <meta name="DCTERMS.authority" title="OVERHEID.Organisatie" content="Statistics Netherlands" />
#     <meta name="DCTERMS.creator" title="OVERHEID.Organisatie" content="Statistics Netherlands" />
#     <meta name="DCTERMS.modified" title="XSD.dateTime" content="16-08-2018T10:41:02" />
#     <meta name="DCTERMS.temporal" content="" />
#     <meta name="DCTERMS.spatial" title="OVERHEID:Koninkrijksdeel" content="The Netherlands" />
#
#     <meta name="description" content="The mission of Statistics Netherlands is to publish reliable and consistent statistical information, that responds to society's demands in this respect." />
#             <meta name="generator" content="CBS Website, Versie 2018.4" />
#
#     <meta name="keywords" content="" />
#     <meta name="robots" content="" />
#     <link rel="alternate" href="https://www.cbs.nl/en-gb" hreflang="en" />
#     <link rel="alternate" href="https://www.cbs.nl/nl-nl" hreflang="nl" />
#     <link rel="shortcut icon" href="https://imagescbs.blob.core.windows.net/cdn/images/cbs_icon.png" type="image/x-icon">
#     <link rel="apple-touch-icon" href="https://imagescbs.blob.core.windows.net/cdn/images/cbs_icon.png">
#
#     <meta name="theme-color" content="#ffffff">
#     <meta name="twitter:card" content="summary_large_image" />
#     <meta name="twitter:site" content="cbs.nl" />
#     <meta name="twitter:site:id" content="statistiekcbs" />
#
#             <meta property="og:image" content="https://www.cbs.nl/Content/images/cbs-ld-logo.png" />
#         <meta property="og:title" content="CBS - Statistics Netherlands" />
#         <meta property="og:type" content="website" />
#         <meta property="og:url" content="https://www.cbs.nl/en-gb" />
#         <meta property="og:locale" content="en_GB">
#         <meta property="og:site_name" content="Statistics Netherlands" />
#         <meta property="og:description" content="The mission of Statistics Netherlands is to publish reliable and consistent statistical information, that responds to society's demands in this respect." />
#
#
#     <!-- Cbs CSS -->
#     <link rel="stylesheet" href="/Content/css/cbs-style.min.css" />
#     <link rel="stylesheet" href="/Content/css/cbs-infographics.min.css" />
#
#             <script type="application/ld+json">
#             {
#   "@context": "http://schema.org",
#
#   "@graph":[
#   {
#   "@type": "WebSite",
#   "url": "https://www.cbs.nl/",
#   "potentialAction": {
#     "@type": "SearchAction",
#     "target": "https://www.cbs.nl/nl-nl/zoeken/?query={search_term_string}",
#     "query-input": "required name=search_term_string"
#   }
#   },
#   {
#   "@type": "Organization",
#   "name": "Centraal Bureau voor de Statistiek",
#   "alternateName": ["CBS","Statistics Netherlands"],
#   "type": "GovernmentOrganization",
#   "url": "https://www.cbs.nl",
#   "logo": "https://www.cbs.nl/Content/images/cbs-ld-logo.png",
#   "address": {
#     "type": "PostalAddress",
#     "addressCountry": "Nederland",
#     "addressLocality": "Den Haag",
#     "addressRegion": "Zuid-Holland",
#     "postalCode": "2492 JP",
#     "streetAddress": "Henri Faasdreef 312, Den Haag"
#   },
#   "contactPoint": {
#     "type": "ContactPoint",
#     "areaServed": "NL",
#     "availableLanguage": [
#       "Dutch",
#       "English"
#     ],
#     "contactType": "customer service",
#     "email": "https://www.cbs.nl/nl-nl/over-ons/contact/contactformulier",
#     "hoursAvailable": "Mo,Tu,We,Th,Fr 08:30-17:30",
#     "name": "Infoservice",
#     "productSupported": "cbs.nl",
#     "telephone": "+31 088 570 7070",
#     "url": "https://www.cbs.nl/nl-nl/over-ons/contact/infoservice"
#   },
#   "sameAs": [
#     "https://www.facebook.com/statistiekcbs",
#     "https://www.twitter.com/statistiekcbs",
#     "https://www.wikidata.org/wiki/Q167086",
#     "https://g.co/kg/m/024xlr",
#     "https://nl.wikipedia.org/wiki/Centraal_Bureau_voor_de_Statistiek",
#     "https://www.youtube.com/user/statistiekcbs",
#     "https://www.linkedin.com/company/centraal-bureau-voor-de-statistiek"
#   ]
# }
#  ]
# }
#         </script>
#
#         <script>
#             var highchartsLogo = '/-/media/cbs/Infographics/highcharts-logo.png';
#             window.Highcharts = undefined;
#         </script>
#         <script src="//code.jquery.com/jquery-2.2.4.min.js"></script>
#     <script src="//f1-na.readspeaker.com/script/37/webReader/webReader.js?pids=wr" type="text/javascript"></script>
#
#     <!--[if lt IE 9]>
#         <script src="/Content/js/libs/bootstrap/html5shiv.min.js"></script>
#         <script src="/Content/js/libs/bootstrap/respond.min.js"></script>
#     <![endif]-->
# </head>
# <body>
#         <a class="sr-only sr-only-focusable hidden-xs" href="#main">Skip to main content</a>
# <header class="cbs-header-mainmenu cbs-header-HoofdMenu">
# 	<div class="inner">
# 		<div class="container group">
# 			<div class="navbar-header">
# 				<button type="button" class="navbar-toggle collapsed" data-toggle="collapse" data-target=".nav-mainmenu" aria-expanded="false" aria-controls="nav-mainmenu">
# 					<span class="sr-only">Change navigation</span>
# 					<span class="icon-bar"></span>
# 					<span class="icon-bar"></span>
# 					<span class="icon-bar"></span>
# 				</button>
# 			</div>
#
# 			<div class="logo">
# 				<a href="/en-gb" aria-label="CBS home"><img src="/Content/images/cbs-brand.svg" alt="Statistics Netherlands"/></a>
# 			</div>
#
# 			<nav id="nav-mainmenu" role="navigation" class="menu collapse navbar-collapse nav-mainmenu">
#
# 	<ul role="menubar">
#
# 				<li role="menuitem" class="" aria-haspopup="true">
# 					<a href="/en-gb/labour-and-income">Labour and income</a>
#
# 						<ul role="menu" class="submenu" aria-haspopup="true">
#
# 								<li role="menuitem"><a href="/en-gb/labour-and-income/labour-and-social-security">Labour and social security</a></li>
# 								<li role="menuitem"><a href="/en-gb/labour-and-income/income-and-spending">Income and spending</a></li>
# 						</ul>
# 				</li>
# 				<li role="menuitem" class="" aria-haspopup="true">
# 					<a href="/en-gb/economy">Economy</a>
#
# 						<ul role="menu" class="submenu" aria-haspopup="true">
#
# 								<li role="menuitem"><a href="/en-gb/economy/enterprises">Enterprises</a></li>
# 								<li role="menuitem"><a href="/en-gb/economy/construction-and-housing">Construction and housing</a></li>
# 								<li role="menuitem"><a href="/en-gb/economy/financial-and-business-services">Financial and business services</a></li>
# 								<li role="menuitem"><a href="/en-gb/economy/trade-hotels-and-restaurants">Trade, hotels and restaurants</a></li>
# 								<li role="menuitem"><a href="/en-gb/economy/manufacturing-and-energy">Manufacturing and energy</a></li>
# 								<li role="menuitem"><a href="/en-gb/economy/international-trade">International trade</a></li>
# 								<li role="menuitem"><a href="/en-gb/economy/agriculture">Agriculture</a></li>
# 								<li role="menuitem"><a href="/en-gb/economy/macroeconomics">Macroeconomics</a></li>
# 								<li role="menuitem"><a href="/en-gb/economy/government-and-politics">Government and politics</a></li>
# 								<li role="menuitem"><a href="/en-gb/economy/prices">Prices</a></li>
# 						</ul>
# 				</li>
# 				<li role="menuitem" class="" aria-haspopup="true">
# 					<a href="/en-gb/society">Society</a>
#
# 						<ul role="menu" class="submenu" aria-haspopup="true">
#
# 								<li role="menuitem"><a href="/en-gb/society/population">Population</a></li>
# 								<li role="menuitem"><a href="/en-gb/society/health-and-welfare">Health and welfare</a></li>
# 								<li role="menuitem"><a href="/en-gb/society/nature-and-environment">Nature and environment</a></li>
# 								<li role="menuitem"><a href="/en-gb/society/education">Education</a></li>
# 								<li role="menuitem"><a href="/en-gb/society/security-and-justice">Security and justice</a></li>
# 								<li role="menuitem"><a href="/en-gb/society/traffic-and-transport">Traffic and transport</a></li>
# 								<li role="menuitem"><a href="/en-gb/society/leisure-and-culture">Leisure and culture</a></li>
# 						</ul>
# 				</li>
# 				<li role="menuitem" class="" aria-haspopup="false"><a href="/en-gb/dossier/regional-statistics">Regional</a></li>
# 				<li role="menuitem" class="" aria-haspopup="false"><a href="/en-gb/about-us/cbs-corporate-news">Corporate</a></li>
# 				<li role="menuitem" class="" aria-haspopup="true">
# 					<a href="/en-gb/figures">Figures</a>
#
# 				</li>
#
# 			<li role="menuitem" class="visible-xs-block" aria-haspopup="false"><a href="/en-gb/our-services">Services</a></li>
# 			<li role="menuitem" class="visible-xs-block" aria-haspopup="false"><a href="/en-gb/our-services/blaise-software">Blaise software</a></li>
# 			<li role="menuitem" class="visible-xs-block" aria-haspopup="false"><a href="/en-gb/about-us">About us</a></li>
#
# 		<li role="menuitem" class="visible-xs-block" aria-haspopup="false"><a href="/nl-nl">Nederlands</a></li>
# 	</ul>
#
# 			</nav>
#
# 			<div class="cbs-header-systemlinks navbar-right hidden-xs">
# 				<a href="/nl-nl">Nederlands</a>
# 			</div>
#
# 			<div class="cbs-header-search navbar-right">
# 				<a class="no-js-search" href="/en-gb/search" aria-label="Search">
# 					<span class="fa fa-search"></span><span class="visually-hidden">Search</span>
# 				</a>
# 			</div>
# 		</div>
# 	</div>
#
# <form action="/api/sitecore/Search/SearchAndRedirect" class="quick-search" method="post">		<div class="overlay"></div>
# 		<div class="searchbox">
# 			<div class="searchform form-group has-feedback">
# 				<input type="hidden" name="fhController" value="SearchController">
# 				<input type="hidden" name="fhAction" value="SearchAndRedirect">
# 				<input type="hidden" name="searchPageUrl" value="/en-gb/search" />
# 				<label for="quicksearchqueryinput" class="visually-hidden">Search</label>
# 				<div class="searchalign">
# 					<input id="quicksearchqueryinput" name="searchqueryinput" type="text" placeholder="Search">
# 					<button type="submit" class="searchbutton" aria-label="Search"><span class="fa fa-search"></span><span class="visually-hidden">Search</span></button>
# 				</div>
# 			</div>
# 		</div>
# </form>
# </header>
#
#
# <main id="main" role="main" class="container container-content container-HoofdMenu homepage-layout no-js" tabindex="-1">
# 	<div class="row">
# 		<h1 class="visually-hidden">Cbs Home</h1>
# 		<section class="col-lg-9 col-md-12 col-sm-12 col-xs-12">
# 	<div class="teaser-container">
# 		<a href="/en-gb/news/2018/39/manufacturing-output-prices-over-5-percent-up">
# 			<figure><img src="https://imagescbs.blob.core.windows.net/images/675541622b67397852386737516b6e69586c747764673d3d/900x450.jpg" alt="" width="900" class="img-responsive" /></figure>
# 				<h2 style="background-color:#0058b8;" class="bottom">Manufacturing output prices over 5 percent up </h2>
# 		</a>
# 	</div>
# </section><section class="col-lg-9 col-md-8 col-sm-8 col-xs-12">
#
#             <h2 class="visually-hidden">Recent news</h2>
#     <div class="multi-rows row">
#             <div class="col-lg-4 col-md-6 col-sm-6 col-xs-12">
#                 <div class="thumbnail">
#                     <a href="/en-gb/news/2018/39/producer-confidence-hardly-changes">
#
#                         <div class="cbs-image-container">
#
#
#         <img class="img-responsive" src="https://imagescbs.blob.core.windows.net/images/494b3979793463696a57796d4c4d373146536d3275513d3d/294x196.jpg" alt="" />
#
# </div>
#
#
#
#                         <div class="caption">
#                             <h3>Producer confidence hardly changes</h3>
#                                 <p>27/09/2018 15:00</p>
#                         </div>
#                     </a>
#                 </div>
#             </div>            <div class="col-lg-4 col-md-6 col-sm-6 col-xs-12">
#                 <div class="thumbnail">
#                     <a href="/en-gb/news/2018/39/1-5-of-manufacturing-exports-are-carry-along-trade">
#
#                         <div class="cbs-image-container">
#
#
#         <img class="img-responsive" src="https://imagescbs.blob.core.windows.net/images/6c56734c4f6347676c41334264397533526c435277413d3d/294x196.jpg" alt="" />
#
# </div>
#
#
#
#                         <div class="caption">
#                             <h3>1/5 of manufacturing exports are carry-along trade</h3>
#                                 <p>27/09/2018 15:00</p>
#                         </div>
#                     </a>
#                 </div>
#             </div>            <div class="col-lg-4 col-md-6 col-sm-6 col-xs-12">
#                 <div class="thumbnail">
#                     <a href="/en-gb/news/2018/37/1-in-5-obese-adults-satisfied-with-body-weight">
#
#                         <div class="cbs-image-container">
#
#
#         <img class="img-responsive" src="https://imagescbs.blob.core.windows.net/images/436955356d4546506d7444484933414f6652615030673d3d/294x196.jpg" alt="" />
#
# </div>
#
#
#
#                         <div class="caption">
#                             <h3>1 in 5 obese adults satisfied with body weight</h3>
#                                 <p>25/09/2018 15:00</p>
#                         </div>
#                     </a>
#                 </div>
#             </div>            <div class="col-lg-4 col-md-6 col-sm-6 col-xs-12">
#                 <div class="thumbnail">
#                     <a href="/en-gb/news/2018/38/budget-surplus-up-to-1-9-percent-of-gdp-in-mid-2018">
#
#                         <div class="cbs-image-container">
#
#
#         <img class="img-responsive" src="https://imagescbs.blob.core.windows.net/images/49656459464e76623744424233336573386b564979673d3d/294x196.jpg" alt="" />
#
# </div>
#
#
#
#                         <div class="caption">
#                             <h3>Budget surplus up to 1.9 percent of GDP in mid-2018</h3>
#                                 <p>24/09/2018 15:00</p>
#                         </div>
#                     </a>
#                 </div>
#             </div>            <div class="col-lg-4 col-md-6 col-sm-6 col-xs-12">
#                 <div class="thumbnail">
#                     <a href="/en-gb/news/2018/38/house-prices-over-9-percent-higher-in-august">
#
#                         <div class="cbs-image-container">
#
#
#         <img class="img-responsive" src="https://imagescbs.blob.core.windows.net/images/66766e67494f594976314f4772432f67346f637968673d3d/294x196.jpg" alt="" />
#
# </div>
#
#
#
#                         <div class="caption">
#                             <h3>House prices over 9 percent higher in August</h3>
#                                 <p>24/09/2018 09:43</p>
#                         </div>
#                     </a>
#                 </div>
#             </div>            <div class="col-lg-4 col-md-6 col-sm-6 col-xs-12">
#                 <div class="thumbnail">
#                     <a href="/en-gb/news/2018/38/gdp-growth-rate-0-8-percent-in-q2-2018">
#
#                         <div class="cbs-image-container">
#
#
#         <img class="img-responsive" src="https://imagescbs.blob.core.windows.net/images/327a4f3262336e616f535a76744c68704162796870513d3d/294x196.jpg" alt="" />
#
# </div>
#
#
#
#                         <div class="caption">
#                             <h3>GDP growth rate 0.8 percent in Q2 2018</h3>
#                                 <p>21/09/2018 15:00</p>
#                         </div>
#                     </a>
#                 </div>
#             </div>            <div class="col-lg-4 col-md-6 col-sm-6 col-xs-12">
#                 <div class="thumbnail">
#                     <a href="/en-gb/news/2018/38/mobile-phones-less-often-secure-than-computers">
#
#                         <div class="cbs-image-container">
#
#
#         <img class="img-responsive" src="https://imagescbs.blob.core.windows.net/images/5072456c73727272366a59473576684c6b4e746778413d3d/294x196.jpg" alt="" />
#
# </div>
#
#
#
#                         <div class="caption">
#                             <h3>Mobile phones less often secure than computers</h3>
#                                 <p>21/09/2018 15:00</p>
#                         </div>
#                     </a>
#                 </div>
#             </div>            <div class="col-lg-4 col-md-6 col-sm-6 col-xs-12">
#                 <div class="thumbnail">
#                     <a href="/en-gb/news/2018/38/economic-situation-unchanged">
#
#                         <div class="cbs-image-container">
#
#
#         <img class="img-responsive" src="https://imagescbs.blob.core.windows.net/images/514b6136454f765061495a75493851396e73494a66773d3d/294x196.jpg" alt="" />
#
# </div>
#
#
#
#                         <div class="caption">
#                             <h3>Economic situation unchanged</h3>
#                                 <p>21/09/2018 15:00</p>
#                         </div>
#                     </a>
#                 </div>
#             </div>            <div class="col-lg-4 col-md-6 col-sm-6 col-xs-12">
#                 <div class="thumbnail">
#                     <a href="/en-gb/news/2018/38/investments-over-6-percent-up-in-july">
#
#                         <div class="cbs-image-container">
#
#
#         <img class="img-responsive" src="https://imagescbs.blob.core.windows.net/images/4259485664513955316977314e6c31636953734836673d3d/294x196.jpg" alt="" />
#
# </div>
#
#
#
#                         <div class="caption">
#                             <h3>Investments over 6 percent up in July</h3>
#                                 <p>21/09/2018 15:00</p>
#                         </div>
#                     </a>
#                 </div>
#             </div>            <div class="col-lg-4 col-md-6 col-sm-6 col-xs-12">
#                 <div class="thumbnail">
#                     <a href="/en-gb/news/2018/38/employment-rate-virtually-the-same-for-six-months">
#
#                         <div class="cbs-image-container">
#
#
#         <img class="img-responsive" src="https://imagescbs.blob.core.windows.net/images/31664456474d6430656e2b324778652b2b504f6942673d3d/294x196.jpg" alt="" />
#
# </div>
#
#
#
#                         <div class="caption">
#                             <h3>Employment rate virtually the same for six months</h3>
#                                 <p>20/09/2018 15:00</p>
#                         </div>
#                     </a>
#                 </div>
#             </div>            <div class="col-lg-4 col-md-6 col-sm-6 col-xs-12">
#                 <div class="thumbnail">
#                     <a href="/en-gb/news/2018/38/household-consumption-nearly-3-percent-up-in-july">
#
#                         <div class="cbs-image-container">
#
#
#         <img class="img-responsive" src="https://imagescbs.blob.core.windows.net/images/56713675416c5a67766347757a534e683473676850673d3d/294x196.jpg" alt="" />
#
# </div>
#
#
#
#                         <div class="caption">
#                             <h3>Household consumption nearly 3 percent up in July</h3>
#                                 <p>20/09/2018 15:00</p>
#                         </div>
#                     </a>
#                 </div>
#             </div>            </div>
# </section>
#
# 		<section id="aside-main" class="col-lg-3 col-md-4 col-sm-4 col-xs-12">
# 			<aside role="complementary" class="sidebar-aqua col-xs-12 aside-override">
# 	<div class="aside-content">
# 		<h2>Featured</h2>
# 				<a href="/en-gb/publication/2018/39/internationalisation-monitor-2018-third-quarter">
# 					<h3>Internationalisation Monitor 2018, third quarter</h3>
# 					<p class="type"></p>
# 				</a>
# 				<a href="https://longreads.cbs.nl/trends18-eng/">
# 					<h3>Trends in the Netherlands 2018</h3>
# 					<p class="type"></p>
# 				</a>
# 				<a href="/en-gb/publication/2018/10/the-sdgs-the-situation-for-the-netherlands">
# 					<h3>The SDGs: the situation for the Netherlands</h3>
# 					<p class="type"></p>
# 				</a>
# 	</div>
# </aside>    <aside role="complementary" class="sidebar-darkblue col-xs-12 aside-override">
#         <div class="aside-content">
#             <h2>CBS video</h2>
# <div class="embed-responsive embed-responsive-16by9"><iframe class="embed-responsive-item" title="YouTube video id O8tdu1KuTRA" src="https://www.youtube.com/embed/O8tdu1KuTRA?rel=0&wmode=transparent&showinfo=0" allowfullscreen></iframe></div>                            <h3 class="title">The Netherlands 10 years after Lehman Brothers (English subtitles available)</h3>        </div>
#     </aside>
# <aside role="complementary" class="sidebar-purple col-xs-12 aside-override">
#     <div class="aside-content">
#             <a href="/en-gb/publication-calendar">
#                 <h2>Expected<span class="fa fa-calendar" title="Publicatiekalender"></span></h2>
#             </a>
#                         <div class="pub-toggle cursor-pointer">
#                     <h3>Bilateral trade with the UK</h3>
#                     <p class="date">03/10/2018 15:00</p>
#                     <p class="pub-description">
#                         How did exports to the United Kingdom develop in the first 7 months of 2018?
#
#
#                             <span class="embargo-event">Available under <a href="https://www.cbs.nl/en-gb/about-us/organisation/publication-policy">embargo</a></span>
#                     </p>
#                 </div>
#                 <div class="pub-toggle cursor-pointer">
#                     <h3>Neighbourhood nuisance on Saba and St Eustatius</h3>
#                     <p class="date">04/10/2018 00:00</p>
#                     <p class="pub-description">
#                         What is the percentage share of residents on St Eustatius who encounter neighbourhood nuisance, and what about Saba?
#
#
#                             <span class="embargo-event">Available under <a href="https://www.cbs.nl/en-gb/about-us/organisation/publication-policy">embargo</a></span>
#                     </p>
#                 </div>
#                 <div class="pub-toggle cursor-pointer">
#                     <h3>Consumer prices</h3>
#                     <p class="date">04/10/2018 15:00</p>
#                     <p class="pub-description">
#                         Price developments for the month of September.
#
#
#                     </p>
#                 </div>
#                 <div class="pub-toggle cursor-pointer">
#                     <h3>Young people's participation in society</h3>
#                     <p class="date">05/10/2018 15:00</p>
#                     <p class="pub-description">
#                         To what degree are young people socially involved, are there any differences among age groups?
#
#
#                             <span class="embargo-event">Available under <a href="https://www.cbs.nl/en-gb/about-us/organisation/publication-policy">embargo</a></span>
#                     </p>
#                 </div>
# 	</div>
# </aside><aside role="complementary" class="sidebar-twitter col-xs-12 aside-override hidden-xs">
# 	<div class="aside-content">
#
# 		<a href="https://twitter.com/statisticscbs">
# 			<h2>
# 				Twitter
#
# 				<span class="fa fa-twitter" title=""></span>
# 			</h2>
# 		</a>
#
# 		<a class="twitter-timeline hide"
# 		   data-widget-id="710405451385540608"
# 		   href="https://twitter.com/statisticscbs?ref_src=twsrc%5Etfw"
# 		   title="Twitter"
# 		   data-chrome="nofooter noborders transparent noheader"></a>
# 	</div>
# </aside>
# <script async="" src="//platform.twitter.com/widgets.js" charset="utf-8"></script>
# 		</section>
# 	</div>
# </main><div class="footer-container">
# 	<footer role="contentinfo" class="container">
# 		<div class="row multi-rows">
# 				<div class="col-lg-3 col-md-3 col-sm-3 col-xs-12">
# 						<p class="title"><a href="/en-gb/our-services">Services</a></p>
#                     <ul>
#                             <li>
#                                 <a href="/en-gb/our-services/customised-services-microdata">Customised services & microdata</a>
#                             </li>
#                             <li>
#                                 <a href="/en-gb/our-services/unique-collaboration-for-big-data-research">Center for Big Data Statistics</a>
#                             </li>
#                             <li>
#                                 <a href="/en-gb/our-services/innovation">Innovation</a>
#                             </li>
#                             <li>
#                                 <a href="/en-gb/our-services/methods">Methodology</a>
#                             </li>
#                             <li>
#                                 <a href="/en-gb/our-services/print-publications">Print publications</a>
#                             </li>
#                             <li>
#                                 <a href="/en-gb/our-services/open-data">Open Data</a>
#                             </li>
#                             <li>
#                                 <a href="/en-gb/visualization/2016/12/calculation-of-rent-increase--private-housing-sector--">Calculation of rent increase</a>
#                             </li>
#                             <li>
#                                 <a href="https://opendata.cbs.nl/statline/#/CBS/en/" target="_blank">Figures/StatLine</a>
#                             </li>
#                             <li>
#                                 <a href="/en-gb/our-services/archive">Archive</a>
#                             </li>
#                     </ul>
# 				</div>
# 				<div class="col-lg-3 col-md-3 col-sm-3 col-xs-12">
# 						<p class="title"><a href="/en-gb/our-services/blaise-software">Blaise software</a></p>
#                     <ul>
#                             <li>
#                                 <a href="http://www.blaise.com/products/general-information">Products</a>
#                             </li>
#                             <li>
#                                 <a href="https://www.blaise.com/company/contact-us">Pricing</a>
#                             </li>
#                             <li>
#                                 <a href="http://blaise.com/support/general-info">Support</a>
#                             </li>
#                             <li>
#                                 <a href="http://www.blaise.com/community/blaise-user-pages">Community</a>
#                             </li>
#                     </ul>
# 				</div>
# 				<div class="col-lg-3 col-md-3 col-sm-3 col-xs-12">
# 						<p class="title"><a href="/en-gb/about-us">About us</a></p>
#                     <ul>
#                             <li>
#                                 <a href="/en-gb/about-us/contact">Contact</a>
#                             </li>
#                             <li>
#                                 <a href="/en-gb/about-us/organisation">Organisation</a>
#                             </li>
#                             <li>
#                                 <a href="/en-gb/about-us/contact/press-office">Press</a>
#                             </li>
#                             <li>
#                                 <a href="/en-gb/about-us/careers-at-cbs">Careers at CBS</a>
#                             </li>
#                             <li>
#                                 <a href="/en-gb/about-us/website">Website</a>
#                             </li>
#                             <li>
#                                 <a href="/en-gb/sitemap">Sitemap</a>
#                             </li>
#                     </ul>
# 				</div>
# 				<div class="col-lg-3 col-md-3 col-sm-3 col-xs-12">
# 						<p class="title"><a href="/en-gb/follow-us">Follow us</a></p>
#                     <ul>
#                             <li>
#                                 <a href="/en-gb/publication-calendar">Publication planning</a>
#                             </li>
#                             <li>
#                                 <a href="https://www.facebook.com/statisticscbs/" target="_blank">Facebook</a>
#                             </li>
#                             <li>
#                                 <a href="https://www.youtube.com/playlist?list=PLekr62u_EkPwIlf3Q1OeJr0neCuOgzOhT" target="_blank">YouTube</a>
#                             </li>
#                             <li>
#                                 <a href="https://twitter.com/StatisticsCBS">Twitter</a>
#                             </li>
#                             <li>
#                                 <a href="/en-gb/rss-feeds">RSS feeds</a>
#                             </li>
#                             <li>
#                                 <a href="/en-gb/newsletters">Newsletters</a>
#                             </li>
#                     </ul>
# 				</div>
# 		</div>
# 	</footer>
# </div><script>var cbsSettings; (function (cbsSettings) { cbsSettings.dictItems = [{"Key":"lastmodified","Phrase":""},{"Key":"publicationdate","Phrase":""},{"Key":"today","Phrase":"today"},{"Key":"tomorrow","Phrase":"tomorrow"},{"Key":"yesterday","Phrase":"yesterday"},{"Key":"days","Phrase":"{0} days ago"},{"Key":"hour","Phrase":"1 hour ago"},{"Key":"hours","Phrase":"{0} hours ago"},{"Key":"minute","Phrase":"1 minute ago"},{"Key":"minutes","Phrase":"{0} minutes ago"}], cbsSettings.search = {enableAutocomplete: true} })(cbsSettings || (cbsSettings = {}));</script>                <script src="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/js/bootstrap.min.js" integrity="sha384-Tc5IQib027qvyjSMfHjOMaLkfuWVxZxUPnCJA7l2mCWNIpG9mGCD8wGNIcPD7Txa" crossorigin="anonymous"></script>
#                 <script src="https://code.highcharts.com/5.0.14/highcharts.js"></script>
#                 <script src="https://code.highcharts.com/maps/6.0.7/modules/map.js"></script>
#                 <script src="https://code.highcharts.com/5.0.14/modules/data.js"></script>
#                 <script src="https://code.highcharts.com/5.0.14/highcharts-more.js"></script>
#                 <script src="https://code.highcharts.com/5.0.14/modules/exporting.js"></script>
#                 <script src="https://code.highcharts.com/5.0.14/modules/offline-exporting.js"></script>
#                 <script src="https://code.highcharts.com/5.0.14/modules/broken-axis.js"></script>
#             <script src="https://imagescbs.blob.core.windows.net/cdn/export-csv.min.js"></script>
#             <script src="/Content/js/libs/highcharts/latest/modules/grouped-categories.min.js"></script>
#             <script src="/Content/js/libs/jquery-lib.min.js"></script>
#             <script src="/Content/js/cbs/cbs.min.js"></script>
#             <script src="/Content/js/libs/wffm.custom.js"></script>
# <script>
# 		(function (i, s, o, g, r, a, m) {
# 			i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function () {
# 				(i[r].q = i[r].q || []).push(arguments)
# 			}, i[r].l = 1 * new Date(); a = s.createElement(o),
# 			m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m)
# 		})(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#
# 		ga('create', 'UA-4397804-1', 'auto');
# 		ga('set', 'anonymizeIp', true);
# 		ga('set', 'forceSSL', true);
# 		ga('send', 'pageview');
#
# 		if (typeof jQuery != 'undefined') {
# 			jQuery(document).ready(function ($) {
# 				var filetypes = /\.(zip*|pdf*|doc*|xls*|pps*|ppt*|epub*)/i;
# 				jQuery('a').each(function () {
# 					var href = jQuery(this).attr('href');
# 					var target = jQuery(this).attr('target');
# 					var text = jQuery(this).text();
# 					var thisEvent = jQuery(this).attr('onclick');
# 					if (href) {
# 						if (href.match(filetypes)) {
# 							jQuery(this).click(function (event) {
# 								if (event.target.href.match(/:\/\/download\.cbs\.nl\//i)) {
# 									event.preventDefault();
# 									var extension = String((/[.]/.exec(href)) ? /[^.]+$/.exec(href) : undefined);
# 									ga('send', {
# 										hitType: 'event',
# 										eventCategory: 'Downloads',
# 										eventAction: extension.toLowerCase(),
# 										eventLabel: event.target.href
# 									});
# 									setTimeout(function () {
# 										eval(thisEvent);
# 										window.open(event.target.href, (!target ? '_self' : target));
# 									}, 200);
# 									return false;
# 								}
# 							});
# 						}
# 					}
# 				});
# 			});
# 		}
# 	</script>
# 	<script type="text/javascript">
# 		/*<![CDATA[*/
# 		(function () {
# 			var sz = document.createElement('script'); sz.type = 'text/javascript'; sz.async = true;
# 			sz.src = '//siteimproveanalytics.com/js/siteanalyze_6009242.js';
# 			var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(sz, s);
# 		})();
# 		/*]]>*/
# 	</script>
# 	<style>
# 		.thumbnail .caption h3 {
# 			font-size: 1.15rem;
# 		}
#
# 		@media (max-width: 767px) {
# 			.thumbnail .caption h3 {
# 				font-size: 1rem;
# 			}
# 		}
#
# 		.panel-title {
# 			font-size: 1rem;
# 		}
# 	</style></body>
# </html>

# %%
soup3 = BeautifulSoup(r3.text, 'html.parser')
print(soup3.title.text)
# Out:
# CBS - Statistics Netherlands

# %%
# Get the URLS to all news articles of CBS:
articles = soup3.find_all("div", class_='thumbnail')
for article in articles:
    link = article.find("a")['href']
    print(link)
# Out:
# /en-gb/news/2018/39/producer-confidence-hardly-changes
# /en-gb/news/2018/39/1-5-of-manufacturing-exports-are-carry-along-trade
# /en-gb/news/2018/37/1-in-5-obese-adults-satisfied-with-body-weight
# /en-gb/news/2018/38/budget-surplus-up-to-1-9-percent-of-gdp-in-mid-2018
# /en-gb/news/2018/38/house-prices-over-9-percent-higher-in-august
# /en-gb/news/2018/38/gdp-growth-rate-0-8-percent-in-q2-2018
# /en-gb/news/2018/38/mobile-phones-less-often-secure-than-computers
# /en-gb/news/2018/38/economic-situation-unchanged
# /en-gb/news/2018/38/investments-over-6-percent-up-in-july
# /en-gb/news/2018/38/employment-rate-virtually-the-same-for-six-months
# /en-gb/news/2018/38/household-consumption-nearly-3-percent-up-in-july

# %%
headlines = soup3.select("div.thumbnail h3")

print(headlines)
# Out:
# [<h3>Producer confidence hardly changes</h3>, <h3>1/5 of manufacturing exports are carry-along trade</h3>, <h3>1 in 5 obese adults satisfied with body weight</h3>, <h3>Budget surplus up to 1.9 percent of GDP in mid-2018</h3>, <h3>House prices over 9 percent higher in August</h3>, <h3>GDP growth rate 0.8 percent in Q2 2018</h3>, <h3>Mobile phones less often secure than computers</h3>, <h3>Economic situation unchanged</h3>, <h3>Investments over 6 percent up in July</h3>, <h3>Employment rate virtually the same for six months</h3>, <h3>Household consumption nearly 3 percent up in July</h3>]

# %%
# Get all texts of news articles of CBS:
articles = soup3.find_all("div", class_='thumbnail')
links3 = []
for article in articles:
    links3.append(article.find("a")['href'])

for link in links3:
    r = requests.get('https://www.cbs.nl'+link)
    soup = BeautifulSoup(r.text, 'html.parser')
    leadtext = soup.find('section', class_='leadtext').text
    print(leadtext)
    time.sleep(1) # in robots.txt CBS advises a delay of 1 second
# Out:
#                 According to Statistics Netherlands (CBS), producer confidence among Dutch manufacturers has hardly changed. Confidence stood at 5.7 in September, down from 5.9 in August. In September, manufacturers were less positive about their future output than in the previous month.
#
#
#                 One-fifth of all exports by Dutch manufacturers consist of products that are not self-manufactured, but supplied along with their own products, a phenomenon referred to as carry-along trade. This is reported by Statistics Netherlands (CBS) in the latest edition of the Internationalisation Monitor, based on new research into this phenomenon.
#
#
#                 Almost half of the total Dutch adult population are moderately or severely overweight. In the period 2015-2017, two in five severely overweight (obese) people indicated that they were dissatisfied with their body weight, while one in five said that they were satisfied. This is reported by Statistics Netherlands (CBS) on the basis of the latest figures.
#
#
#                 Government revenues were nearly 5 billion euros higher in the first six months of 2018 than in the same period last year. This resulted in a year-on-year increase in the budget surplus, equivalent to 1.9 percent of gross domestic product (GDP), measured from Q3 2017 up to and including Q2 2018. Government debt continued to decline steadily in the first six months of 2018. By the end of June this year, government debt stood at 54 percent of GDP; this is a decline of 3 percentage points of GDP since the beginning of this year. Statistics Netherlands (CBS) reports this based on new government finance statistics.
#
#
#                 In August 2018, prices of owner-occupied houses (excluding new constructions) were on average 9.3 percent higher than in the same month last year. The price increase was higher than in the preceding months. This is according to the price index of owner-occupied houses, a joint publication by Statistics Netherlands (CBS) and the Land Registry Office (Kadaster).
#
#
#                 According to the second estimate conducted by Statistics Netherlands (CBS), gross domestic product (GDP) grew by 0.8 percent in Q2 2018 relative to Q1 2018. The second GDP estimate is published approximately 90 days after the end of the quarter. Growth was mainly due to an increase in exports. Investments and household consumption were up again as well. GDP has grown continually over the past 17 quarters.
#
#
#                 Mobile phone users indicate they are less likely to have security software installed on their device than computer users. Nearly one-quarter of respondents say their mobile device is not secure at all and an equally large share report they do not know whether it has any form of protection. This is evident from the Cyber Security Monitor 2018 published by Statistics Netherlands (CBS).
#
#
#                 According to the CBS Business Cycle Tracer, the economic situation has remained unchanged in September compared to the previous month. Statistics Netherlands (CBS) reports that all indicators in the Tracer as published in mid-September are performing above the level of their long-term trend.
#
#
#                 Statistics Netherlands (CBS) reports that the volume of investments in tangible fixed assets was 6.2 percent up in July 2018 relative to the same month last year. The year-on-year growth was less substantial than in the preceding month. In July 2018, investments in dwellings, buildings, cars, trucks and machinery were up in particular. Investments in aircraft on the other hand, were considerably lower.
#
#
#                 Between June and August 2018, the number of people aged 15 to 74 in paid employment grew by an average of 20 thousand per month. Statistics Netherlands (CBS) reports that total employment reached 8.8 million in August, as indicated by the latest figures. More than 4.1 million people did not have paid work for a variety of reasons. This included 353 thousand people who indicated they had recently looked and were immediately available for work. These are the unemployed according to the definition of the International Labour Organization (ILO). On average, their number remained almost the same over the previous three months. As a result, the unemployment rate in the Dutch labour force stood at 3.9 in August. This has been virtually the same for six months.
#
#
#                 According to figures released by Statistics Netherlands (CBS), Dutch household consumption was 2.6 percent up in July 2018 over July 2017. The growth rate was the same as in the previous month. In July 2018, consumers mainly spent more on food, beverages and tobacco.
